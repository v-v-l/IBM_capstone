# %% [markdown]
# # Finding of differences between Toronto and Manhattan

# %% [markdown]
# In Module 3, we explored New York City and the city of Toronto and segmented and clustered their neighborhoods. Both cities are very diverse and are the financial capitals of their respective countries. One interesting idea would be to compare the neighborhoods of the two cities and determine how similar or dissimilar they are. Is New York City more like Toronto or Paris or some other multicultural city? I will leave it to you to refine this idea.
#
# ### Description of the problem:
#
# Goal of this research is to find differences or similarities across Toronto and Manhattan.
#
# ##### For solving this question the following datasources being used:
#     - Data on NY neighborhoods from Week 3 lab
#     - Data on Toronto from Week 3 assignment
#     - Data from Foursquare on types of venues in both regions.
#
#
# This project could be interesting for individuals travelling to respective regions or to the individuals searching for employment in the regions. Comparison of the cities specifics could be additional pros or cons.

# %% [markdown]
# ### Methodology

# %% [markdown]
# As step 1 of the research we need to obtain data on both regions.
# We will do this by loading the respective data and transforming it to dataframes.
#
# We will utilize power of folium to show initial location of each neighborhood and clasterization of the later stages.
#
# Having the data obtainded we will append it with the Foursqaure's data on type of venues in the neighborhoods of each region.
#
# To do k-means clustering algorithm on the data we need to:
#     - do one hot encoding whith mean frequency of occurence of each category of venues in the claster;
#     - take top-10 venues in each neighborhood;
#     - on this data do the clustering algorithm;

# %% [markdown]
# # Outcomes

# %% [markdown]
# #### Top-10 categories in each region

# %%
# get percentage of top-10 venue types in Toronto
top_10_toronto = pd.DataFrame((toronto_venues['Venue Category'].value_counts()/toronto_venues.shape[0]*100)[0:10])

# %%
# get percentage of top-10 venue types in Manhattan
top_10_manhattan = pd.DataFrame((manhattan_venues['Venue Category'].value_counts()/manhattan_venues.shape[0]*100)[0:10])

# %%
top_10_manhattan.rename(columns={"Venue Category": "Manhattan"}, inplace = True)
top_10_toronto.rename(columns={"Venue Category": "Toronto"}, inplace = True)

# %%
categories = pd.merge(top_10_toronto, top_10_manhattan, left_on=None, right_on=None, left_index=True, right_index=True, how = 'outer')
print(categories.sort_values(by = 'Toronto', ascending = False))
# Out:
#                        Toronto  Manhattan
# Coffee Shop           8.834586   4.620462
# Café                  5.639098   2.541254
# Restaurant            3.508772        NaN
# Italian Restaurant    2.631579   3.300330
# Park                  2.130326   2.376238
# Japanese Restaurant   2.067669        NaN
# Hotel                 1.942356   2.046205
# Bakery                1.817043   2.112211
# Bar                   1.691729        NaN
# Gym                   1.629073   1.815182
# American Restaurant        NaN   2.013201
# Gym / Fitness Center       NaN   1.947195
# Pizza Place                NaN   2.541254

# %% [markdown]
# As could be seen from the table above, Toronto has more Coffee Shops and Cafe as percentage from total categories value, therefore we could assume that Toronto's citizen like to dring more coffee.
#
# Additionally Bars and Japaniese restaurants are not as popular on Manhattas as in Torronto which could be an indicater of different structure of the population.
#
# On the opposite side, number of Gym and Fitness Centres are higher on Manhattan => healthier lifestyle could be expected.
#
# However both of the prepositions requires additional research.

# %% [markdown]
# ### Clusterisation presented visually

# %% [markdown]
# If we look on the maps, concentration of similar clusters is higher in Toronto with low level of differenciation comparing to Manhattan.

# %%
display(map_clusters_toronto)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Majority of neighborhoods are belong to "cluster 4" which characterized by Coffee Shop, Cafe or Bars.

# %%
display(toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]])
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 2    Downtown Toronto               4           Coffee Shop
# 4    Downtown Toronto               4           Coffee Shop
# 9    Downtown Toronto               4        Clothing Store
# 15   Downtown Toronto               4           Coffee Shop
# 19       East Toronto               4                 Trail
# 20   Downtown Toronto               4           Coffee Shop
# 24   Downtown Toronto               4           Coffee Shop
# 30   Downtown Toronto               4           Coffee Shop
# 31       West Toronto               4                Bakery
# 36   Downtown Toronto               4           Coffee Shop
# 37       West Toronto               4                   Bar
# 41       East Toronto               4      Greek Restaurant
# 42   Downtown Toronto               4           Coffee Shop
# 47       East Toronto               4                  Park
# 48   Downtown Toronto               4           Coffee Shop
# 54       East Toronto               4                  Café
# 67    Central Toronto               4                  Park
# 69       West Toronto               4       Thai Restaurant
# 73    Central Toronto               4        Clothing Store
# 74    Central Toronto               4                  Café
# 75       West Toronto               4             Gift Shop
# 79    Central Toronto               4        Sandwich Place
# 80   Downtown Toronto               4                  Café
# 81       West Toronto               4           Coffee Shop
# 84   Downtown Toronto               4                  Café
# 86    Central Toronto               4                   Pub
# 87   Downtown Toronto               4        Airport Lounge
# 92   Downtown Toronto               4           Coffee Shop
# 96   Downtown Toronto               4           Coffee Shop
# 97   Downtown Toronto               4           Coffee Shop
# 99   Downtown Toronto               4   Japanese Restaurant
# 100      East Toronto               4    Light Rail Station
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 2                    Park                Bakery                   Pub
# 4        Sushi Restaurant           Yoga Studio              Creperie
# 9             Coffee Shop                  Café       Bubble Tea Shop
# 15                   Café          Cocktail Bar   American Restaurant
# 19                    Pub     Health Food Store               Dog Run
# 20           Cocktail Bar              Beer Bar                Bakery
# 24     Italian Restaurant        Sandwich Place                  Café
# 30                   Café            Restaurant         Deli / Bodega
# 31               Pharmacy         Grocery Store                   Bar
# 36               Aquarium                  Café                 Hotel
# 37             Restaurant      Asian Restaurant           Men's Store
# 41     Italian Restaurant           Coffee Shop            Restaurant
# 42                   Café                 Hotel            Restaurant
# 47   Fast Food Restaurant        Sandwich Place           Coffee Shop
# 48                   Café            Restaurant                 Hotel
# 54            Coffee Shop                Bakery             Gastropub
# 67         Breakfast Spot      Department Store                 Hotel
# 69     Mexican Restaurant                  Café                  Park
# 73    Sporting Goods Shop           Coffee Shop  Gym / Fitness Center
# 74         Sandwich Place           Coffee Shop         Grocery Store
# 75         Breakfast Spot          Dessert Shop    Italian Restaurant
# 79           Dessert Shop                  Café           Coffee Shop
# 80    Japanese Restaurant                   Bar    Italian Restaurant
# 81                   Café    Italian Restaurant           Pizza Place
# 84     Mexican Restaurant           Coffee Shop                Bakery
# 86            Coffee Shop   American Restaurant           Supermarket
# 87        Airport Service      Airport Terminal           Coffee Shop
# 92     Seafood Restaurant                  Café   Japanese Restaurant
# 96     Chinese Restaurant            Restaurant    Italian Restaurant
# 97                   Café                   Gym            Restaurant
# 99       Sushi Restaurant           Coffee Shop            Restaurant
# 100           Yoga Studio         Auto Workshop                  Park
#
#              5th Most Common Venue          6th Most Common Venue  \
# 2                   Breakfast Spot                           Café
# 4                         Beer Bar                  Smoothie Shop
# 9              Japanese Restaurant             Italian Restaurant
# 15                       Gastropub                       Beer Bar
# 19                Department Store                   Dessert Shop
# 20              Seafood Restaurant                    Cheese Shop
# 24                             Bar                Bubble Tea Shop
# 30                             Gym                          Hotel
# 31                            Café                           Park
# 36             Fried Chicken Joint                 Scenic Lookout
# 37   Vegetarian / Vegan Restaurant                           Café
# 41                  Ice Cream Shop         Furniture / Home Store
# 42             American Restaurant            Japanese Restaurant
# 47               Food & Drink Shop                        Brewery
# 48                             Gym            American Restaurant
# 54                         Brewery            American Restaurant
# 67               Food & Drink Shop                 Sandwich Place
# 69             Fried Chicken Joint                         Bakery
# 73            Fast Food Restaurant                          Diner
# 74                             Pub      Middle Eastern Restaurant
# 75                       Bookstore                     Restaurant
# 79              Italian Restaurant               Sushi Restaurant
# 80                       Bookstore                     Restaurant
# 81                Sushi Restaurant                            Pub
# 84           Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 86                Sushi Restaurant                     Sports Bar
# 87                   Boat or Ferry            Rental Car Location
# 92                    Cocktail Bar                     Restaurant
# 96                          Bakery                            Pub
# 97                           Hotel            Japanese Restaurant
# 99                            Café                            Pub
# 100                     Comic Shop                    Pizza Place
#
#          7th Most Common Venue        8th Most Common Venue  \
# 2                      Theater               Cosmetics Shop
# 4               Sandwich Place                Burrito Place
# 9    Middle Eastern Restaurant               Cosmetics Shop
# 15          Seafood Restaurant                     Creperie
# 19                       Diner               Discount Store
# 20                        Café                   Restaurant
# 24              Ice Cream Shop                  Salad Place
# 30              Clothing Store              Thai Restaurant
# 31        Brazilian Restaurant                  Music Venue
# 36         Sporting Goods Shop                   Restaurant
# 37                    Boutique                      Brewery
# 41     Fruit & Vegetable Store                          Pub
# 42          Italian Restaurant                  Salad Place
# 47                Liquor Store                   Board Shop
# 48          Seafood Restaurant           Italian Restaurant
# 54                         Bar           Seafood Restaurant
# 67                Dance Studio                          Gym
# 69   Cajun / Creole Restaurant                  Flea Market
# 73                Dessert Shop           Mexican Restaurant
# 74                   BBQ Joint                   Donut Shop
# 75                 Coffee Shop  Eastern European Restaurant
# 79                         Gym                  Pizza Place
# 80                      Bakery           Chinese Restaurant
# 81                 Yoga Studio                          Bar
# 84                 Gaming Cafe                          Bar
# 86                        Bank          Fried Chicken Joint
# 87            Sculpture Garden                        Plane
# 92                    Beer Bar           Italian Restaurant
# 96                        Café                  Pizza Place
# 97                 Salad Place          American Restaurant
# 99                 Men's Store     Mediterranean Restaurant
# 100           Recording Studio                Burrito Place
#
#     9th Most Common Venue     10th Most Common Venue
# 2              Shoe Store                 Restaurant
# 4                    Café         College Auditorium
# 9              Restaurant                      Diner
# 15                    Gym             Lingerie Store
# 19    Distribution Center              Women's Store
# 20          Grocery Store        Japanese Restaurant
# 24    Japanese Restaurant            Thai Restaurant
# 30       Sushi Restaurant         Seafood Restaurant
# 31                Brewery  Middle Eastern Restaurant
# 36     Italian Restaurant                    Brewery
# 37            Record Shop                Pizza Place
# 41            Pizza Place                     Lounge
# 42     Seafood Restaurant               Concert Hall
# 47             Restaurant              Burrito Place
# 48          Deli / Bodega        Japanese Restaurant
# 54              Bookstore             Sandwich Place
# 67                Dog Run              Deli / Bodega
# 69              Bookstore                  Speakeasy
# 73                   Park         Chinese Restaurant
# 74       Asian Restaurant               Burger Joint
# 75                Dog Run           Cuban Restaurant
# 79                  Diner                        Bar
# 80                    Pub               Dessert Shop
# 81                    Spa          Fish & Chips Shop
# 84           Dessert Shop              Smoothie Shop
# 86             Restaurant                 Bagel Shop
# 87                    Bar            Harbor / Marina
# 92         Breakfast Spot                   Creperie
# 96              Pet Store             Sandwich Place
# 97       Asian Restaurant                 Steakhouse
# 99                  Hotel                    Gay Bar
# 100            Restaurant                    Brewery

# %%
display(toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]])
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 83   Central Toronto               1                  Park
# 91  Downtown Toronto               1                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 83         Women's Store         Deli / Bodega           Event Space
# 91            Playground                 Trail          Cupcake Shop
#
#    5th Most Common Venue        6th Most Common Venue  \
# 83  Ethiopian Restaurant            Electronics Store
# 91     Electronics Store  Eastern European Restaurant
#
#           7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 83  Eastern European Restaurant            Donut Shop      Doner Restaurant
# 91                   Donut Shop      Doner Restaurant               Dog Run
#
#    10th Most Common Venue
# 83                Dog Run
# 91    Distribution Center

# %%
display(map_clusters_manhattan)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
display(manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 1, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]])
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 14             Clinton               Theater           Coffee Shop
# 15             Midtown           Coffee Shop               Theater
# 16         Murray Hill                 Hotel        Sandwich Place
# 21             Tribeca                  Park    Italian Restaurant
# 28   Battery Park City                  Park                 Hotel
# 29  Financial District           Coffee Shop           Pizza Place
# 30       Carnegie Hill           Coffee Shop           Pizza Place
# 32        Civic Center                 Hotel           Coffee Shop
# 33       Midtown South     Korean Restaurant                 Hotel
# 38            Flatiron  Gym / Fitness Center    Italian Restaurant
# 39        Hudson Yards                 Hotel  Gym / Fitness Center
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 14  Gym / Fitness Center             Wine Shop                   Gym
# 15                 Hotel                Bakery      Cuban Restaurant
# 16           Coffee Shop           Pizza Place  Gym / Fitness Center
# 21                   Spa                  Café              Wine Bar
# 28             Wine Shop         Boat or Ferry                   Gym
# 29                 Hotel        Sandwich Place   American Restaurant
# 30           Yoga Studio             Bookstore   Japanese Restaurant
# 32     French Restaurant                  Park                   Spa
# 33          Burger Joint                  Café   Japanese Restaurant
# 38             Wine Shop   American Restaurant    Salon / Barbershop
# 39    Italian Restaurant   American Restaurant               Dog Run
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 14                 Hotel                   Spa    Italian Restaurant
# 15           Pizza Place        Clothing Store            Steakhouse
# 16            Steakhouse             Juice Bar   Japanese Restaurant
# 21            Steakhouse      Greek Restaurant     French Restaurant
# 28           Coffee Shop         Memorial Site         Shopping Mall
# 29    Falafel Restaurant           Salad Place            Steakhouse
# 30         Grocery Store                   Gym                  Café
# 32   American Restaurant          Cocktail Bar      Sushi Restaurant
# 33  Gym / Fitness Center          Dessert Shop           Coffee Shop
# 38        Cosmetics Shop                  Park     Outdoor Sculpture
# 39                  Café            Restaurant           Coffee Shop
#
#    9th Most Common Venue    10th Most Common Venue
# 14           Pizza Place       American Restaurant
# 15        Cosmetics Shop               Tailor Shop
# 16          Burger Joint  Mediterranean Restaurant
# 21                Bakery               Men's Store
# 28          Gourmet Shop                Food Court
# 29          Cocktail Bar                      Café
# 30             Wine Shop     Vietnamese Restaurant
# 32  Gym / Fitness Center               Yoga Studio
# 33                Lounge                 Hotel Bar
# 38           Yoga Studio    Furniture / Home Store
# 39                  Park             Boat or Ferry

# %% [markdown]
# ### Conclusion
#
# Presenter research clearly shown differentiation of regions. If you prefer to drink coffee and go to bars, you should probably take Toronto.
#
# On the opposite, if you prefere healthy lifestyle, Manhattan is your choice.
#
# Within the scoup of this resear

# %% [markdown]
# ### Research

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import json

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# import k-means from clustering stage
from sklearn.cluster import KMeans

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import folium # plotting library

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
# function to get the data on venues
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

#function to sort the venues in descending order.
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# # Load Toronto data

# %%
#loading (scraping) the data
codes_df = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")[0]

#get only assigned Borough
df = codes_df[codes_df['Borough'] != 'Not assigned']

#reading file with coordinates
coordinates = pd.read_csv('https://cocl.us/Geospatial_data')
#coordinates

#add coordinates to initial dataframe
df = pd.merge(df, coordinates, how = 'left', on = 'Postal Code')
df.head()

#getting coordinates for Toronto
neighborhoods = df[df.Borough.str.contains('Toronto')]

#get Toronto coordinates
address = 'Toronto'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
#print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

# create map of Totonto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to the map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, let's get the top 100 venues that are in Marble Hill within a radius of 500 meters.

# %%
# Connection


#print('Your credentails:')
#print('CLIENT_ID: ' + CLIENT_ID)
#print('CLIENT_SECRET:' + CLIENT_SECRET)

# %%
#define url params
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

results = requests.get(url).json()

# %%
#get information on Toronto_venues
toronto_venues = getNearbyVenues(names=neighborhoods['Neighborhood'],
                                   latitudes=neighborhoods['Latitude'],
                                   longitudes=neighborhoods['Longitude']
                                  )

toronto_venues.head()

# %% [markdown]
# Analysing

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()

# %% [markdown]
# Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
#group rows by neighborhood and by taking the mean of the 
#frequency of occurrence of each category

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

#create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
        
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

#neighborhoods_venues_sorted.head()

# %% [markdown]
# ## Cluster Neighborhoods of Toronto

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

#create the new dataframe and display the top 10 venues for each neighborhood

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = neighborhoods

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

#toronto_merged.head() # check the last columns!



# create map
map_clusters_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters_toronto)
       
map_clusters_toronto

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]

# %% [markdown]
# # Load NY data

# %%
with open('Data/nyu_2451_34572-geojson.json') as json_data:
    newyork_data = json.load(json_data)

neighborhoods_ny_data = newyork_data['features']

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods_ny = pd.DataFrame(columns=column_names)

for data in neighborhoods_ny_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods_ny = neighborhoods_ny.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
#get Manhattan data
manhattan_data = neighborhoods_ny[neighborhoods_ny['Borough'] == 'Manhattan'].reset_index(drop=True)

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))

# create map of New York using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan

# %%
#get information on NY venues
manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
manhattan_venues.head()

# %% [markdown]
# Analysing

# %%
# one hot encoding
manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
manhattan_onehot['Neighborhood'] = manhattan_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]

manhattan_onehot.head()

# %% [markdown]
# Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
#group rows by neighborhood and by taking the mean of the 
#frequency of occurrence of each category

manhattan_grouped = manhattan_onehot.groupby('Neighborhood').mean().reset_index()

#create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = manhattan_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(manhattan_grouped.iloc[ind, :], num_top_venues)

#neighborhoods_venues_sorted.head()

# %% [markdown]
# ## Cluster Neighborhoods of Manhattan

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))

# create map of New York using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=10)

# set number of clusters
kclusters = 5

manhattan_grouped_clustering = manhattan_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(manhattan_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

manhattan_merged = manhattan_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
manhattan_merged = manhattan_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# create map
map_clusters_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters_manhattan)
       
map_clusters_manhattan

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 4, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 1, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
